# %% [markdown]
# # VISUALIZATION AND ANALYSIS

# %% [markdown]
# -  @dog_rates/WeRateDogs_@_(https://twitter.com/dog_rates) is one of the most famous
# Twitter accounts with 7.81 million at the hour of composing this report.
# This record is devoted to rate canines, with an exceptional rating framework
#
#
#
# - Rating framework
#
#
#
# -  Since these records began at 15/11/2015 and the administrator utilizes an exceptional rating arrangement of
# denominator of 10 and the numerators are continuously surpassing 10 most likely could arrive at 12,
# greatest at 14 may at times arrive at hundreds as 420 or even thousands as 1776. all of this
# make a verbal exchange and spread for this record
#
#
#
# -  One discussion in a similar setting makes a moment hit to the record, check for more
# (https://knowyourmeme.com/images/theyre-gpod-canines brent)
#
#
#
#
# -  Source
# This investigation depends on various datasets gathered and cleaned to shape 1915 records
#
#
#
#
# -  Motive
#
#
# -  In this report I would like to answer some question about;
#
# - What's the most source used by followers to share their dog's nice photo?
# - Which is the most popular day/month to post a dog photo?
# - Which is the most common dog name?
# - How do @WeRateDogs account rate dogs?
# - Which is the most common breed?

# %% [markdown]
# # 1- What's the most source used by followers to share their dog's nice photo?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#
# - It is clear from the above that Twitter app in Iphone has the most share 93% which is better explained by :
# -	The ease of use to take a shot for a dog from the app
# -	The high resolution of cameras

# %% [markdown]
# # 2. Which is the most popular day/month to post a dog photo?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  -  Clearly individuals will quite often post their dogs photographs in Monday/December
#
# -	Curiously, most day is Monday, may show that the greater part of devotees is out of pressure (might be not laborers)
# -	The top month is December may be deciphered as the hour of Christmas and New Year get-aways, so individuals will in general go out with their canines and make efforts

# %% [markdown]
# # 3.Which is the most common dog name

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It is clear enough, that most utilized Dog name in our dataset is Charlie, trailed by Oliver and Lucy! As most people tend to use real names often

# %% [markdown]
# # 4.  How do @WeRateDogs account rate dogs?

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# - We can notice from the above plot that the most frequent score is around 12, and the maximum is 14

# %% [markdown]
# # 5. Which is the most common breed?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Here, The most well-known breed in our example is Golden Retriever
#
#
# condition:
# -	The varieties information contains a ton of invalid qualities Likewise to think about that this information is given by a neural network model
